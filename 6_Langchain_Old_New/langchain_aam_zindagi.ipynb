# %%
import random 

class NakliLLM:

    def __init__(self):
        print('LLM Created')

    def predict(self, prompt):

        response_list = [
            'I am very talented person',
            'Law of attraction works',
            'No one can distract me',
            'I won tennis match',
            'I am AI enginner'
        ]

        return {'response': random.choice(response_list)}

# %%
class NakliPromptTemplate:
    def __init__(self, template, input_variables):
        self.template = template
        self.input_variables = input_variables
    
    def format(self, input_dict):
        return self.template.format(**input_dict)

# %%
template = NakliPromptTemplate(
    template = 'Write a {length} poem about {topic}',
    input_variables = ['length', 'topic']
)

# %%
prompt = template.format({'length':'long', 'topic':'india'})

# %%
template.format({'length':'long', 'topic':'india'})
# Out:
# 'Write a long poem about india'

# %%
llm = NakliLLM()
# Out:
# LLM Created

# %%
llm.predict(prompt)
# Out:
# {'response': 'I am AI enginner'}

# %%
class NakliLLMChain:
    def __init__(self, llm, prompt):
        self.llm = llm
        self.prompt = prompt

    def run(self, input_dict):

        final_prompt = self.prompt.format(input_dict)
        result = self.llm.predict(final_prompt)

        return result['response']

# %%
template = NakliPromptTemplate(
    template = 'Write a {length} poem about {topic}',
    input_variables = ['length', 'topic']
)

# %%
gpt = NakliLLM()
# Out:
# LLM Created

# %%
chain = NakliLLMChain(llm, template)

# %%
chain.run({'length':'short', 'topic': 'india'})
# Out:
# 'Law of attraction works'

# %%
chain.run({'length':'long', 'topic': 'cricket'})
# Out:
# 'I am AI enginner'
